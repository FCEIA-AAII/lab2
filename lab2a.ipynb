# %% [markdown]
# # Lab 2a: Clasificación Binaria

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FCEIA-AAII/lab1/blob/main/lab2a.ipynb)

# %% [markdown]
# ## Preparación del entorno.
#
# Si no estamos parados en el repo, clonar y cd al repo. Esto nos permite usar el mismo notebook tanto local como en Google Colab.

# %%
import os

REPO_NAME = "lab2"
if REPO_NAME not in os.getcwd():
  if not os.path.exists(REPO_NAME):
    # !git clone https://github.com/FCEIA-AAII/{REPO_NAME}.git
  os.chdir(REPO_NAME)

# %% [markdown]
# ## Análisis Exploratorio.

# %% [markdown]
# Importar librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf

# %%
# Configurar para que TensorFlow utilice la GPU por defecto
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Configurar para que TensorFlow asigne memoria dinámicamente
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        # Especificar la GPU por defecto
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Manejar error
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# Cargar y visualizar los datos.

# %%
data = pd.read_csv('dataset-lab2.csv')
print(data.head())
# Out:
#          X1        X2    Y
# 0  0.812761  0.739781  1.0
# 1  0.812057  0.259719  1.0
# 2  0.857711  0.434979  1.0
# 3  0.460648  0.432698  0.0
# 4  0.776138  0.635665  1.0

# %% [markdown]
# Plot de los datos.

# %%
X1 = data['X1'].to_numpy()
X2 = data['X2'].to_numpy()
Y = data['Y'].to_numpy()

print("X1 shape:", X1.shape)
print("X2 shape:", X2.shape)
print("Y shape:", Y.shape)

plt.scatter(X1[Y == 0], X2[Y == 0], color='red', alpha=0.5)
plt.scatter(X1[Y == 1], X2[Y == 1], color='green', alpha=0.5)

plt.xlabel('Promedio Parciales')
plt.ylabel('Promedio TPs')

plt.show()
# Out:
# X1 shape: (1000,)
# X2 shape: (1000,)
# Y shape: (1000,)

# %% [markdown]
# Definimos nuestro modelo usando tensorflow.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(2,)),
    tf.keras.layers.Dense(units=1, activation='sigmoid')
])

# %% [markdown]
# Definimos una función para plotear la frontera de decisión sobre los datos.

# %%
def plot_results(X1, X2, Y, model):
    plt.scatter(X1[Y == 0], X2[Y == 0], color='red', alpha=0.5)
    plt.scatter(X1[Y == 1], X2[Y == 1], color='green', alpha=0.5)

    plt.xlabel('Promedio Parciales')
    plt.ylabel('Promedio TPs')

    x1 = np.linspace(0, 1, 100)
    x2 = np.linspace(0, 1, 100)

    # Create a meshgrid with all the possible combinations of x1 and x2
    x1, x2 = np.meshgrid(x1, x2, indexing='ij')

    # This is equivalent to
    # x = np.array([[i, j] for i in x1 for j in x2])
    x = np.array([x1.ravel(), x2.ravel()]).T

    # Predict the value for each point in the meshgrid
    y = model.predict(x).reshape(x1.shape)

    # Use cmap red and green
    plt.contourf(x1, x2, y, alpha=0.1, cmap='RdYlGn')

    # Draw the decision boundary
    plt.contour(x1, x2, y, levels=[0.5], colors='blue')

    plt.xlim(0, 1)
    plt.ylim(0, 1)

    plt.show()

plot_results(X1, X2, Y, model)
# Out:
# 313/313 [==============================] - 0s 864us/step

# %% [markdown]
# Entrenamos el modelo.

# %%
# El optimizador es el algoritmo que se encarga de minimizar la función de costo
# Más adelante vamos a ver más en detalle cómo funciona cada uno
# Por ahora, usamos el optimizador Adam, es una versión mejorada de gradient descent.
optimizer = tf.keras.optimizers.Adam(learning_rate=0.5)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

x = np.column_stack([X1, X2])
y = Y
print(x.shape)
print(y.shape)
model.fit(x=x, y=y, epochs=50)
# Out:
# (1000, 2)
# (1000,)
# Epoch 1/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3892 - accuracy: 0.8410
# Epoch 2/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2333 - accuracy: 0.9150
# Epoch 3/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1962 - accuracy: 0.9200
# Epoch 4/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.1927 - accuracy: 0.9160
# Epoch 5/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1953 - accuracy: 0.9190
# Epoch 6/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1940 - accuracy: 0.9160
# Epoch 7/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1855 - accuracy: 0.9120
# Epoch 8/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1843 - accuracy: 0.9140
# Epoch 9/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2005 - accuracy: 0.9030
# Epoch 10/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1858 - accuracy: 0.9160
# Epoch 11/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1851 - accuracy: 0.9190
# Epoch 12/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1866 - accuracy: 0.9140
# Epoch 13/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1841 - accuracy: 0.9130
# Epoch 14/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1816 - accuracy: 0.9220
# Epoch 15/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1774 - accuracy: 0.9190
# Epoch 16/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1823 - accuracy: 0.9170
# Epoch 17/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1829 - accuracy: 0.9200
# Epoch 18/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1863 - accuracy: 0.9110
# Epoch 19/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1829 - accuracy: 0.9140
# Epoch 20/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1806 - accuracy: 0.9130
# Epoch 21/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1818 - accuracy: 0.9150
# Epoch 22/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1764 - accuracy: 0.9180
# Epoch 23/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1951 - accuracy: 0.9140
# Epoch 24/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1787 - accuracy: 0.9170
# Epoch 25/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1763 - accuracy: 0.9150
# Epoch 26/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1858 - accuracy: 0.9070
# Epoch 27/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1760 - accuracy: 0.9190
# Epoch 28/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1786 - accuracy: 0.9200
# Epoch 29/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1787 - accuracy: 0.9150
# Epoch 30/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1773 - accuracy: 0.9180
# Epoch 31/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1832 - accuracy: 0.9150
# Epoch 32/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1775 - accuracy: 0.9240
# Epoch 33/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1874 - accuracy: 0.9160
# Epoch 34/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1920 - accuracy: 0.9090
# Epoch 35/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1791 - accuracy: 0.9160
# Epoch 36/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1964 - accuracy: 0.9160
# Epoch 37/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1818 - accuracy: 0.9210
# Epoch 38/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1859 - accuracy: 0.9100
# Epoch 39/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1816 - accuracy: 0.9170
# Epoch 40/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1775 - accuracy: 0.9170
# Epoch 41/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1761 - accuracy: 0.9180
# Epoch 42/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1893 - accuracy: 0.9150
# Epoch 43/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1814 - accuracy: 0.9150
# Epoch 44/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1816 - accuracy: 0.9130
# Epoch 45/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1809 - accuracy: 0.9160
# Epoch 46/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1777 - accuracy: 0.9200
# Epoch 47/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1849 - accuracy: 0.9170
# Epoch 48/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1819 - accuracy: 0.9140
# Epoch 49/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1858 - accuracy: 0.9140
# Epoch 50/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1856 - accuracy: 0.9160

# %% [markdown]
# Plot de la frontera de decisión.

# %%
plot_results(X1, X2, Y, model)
# Out:
# 313/313 [==============================] - 0s 844us/step

# %% [markdown]
# Vemos que el modelo no tiene la complejidad suficiente como para representar la frontera de decisión.
#
# Probemos entonces con un modelo más complejo.
#
# *Nota: el entrenamiento puede no converger a una solución óptima. Se propone correr el entrenamiento varias veces hasta que se obtenga una solución aceptable. Más adelante estudiaremos técnicas para mejorar la convergencia.*

# %%
model = tf.keras.Sequential([
    # Completar con:
    # 1. Una capa de entrada con las dimensiones correspondientes.
    # 2. Una capa oculta con 2 neuronas y función de activación sigmoid.
    # 3. Una capa de salida con 1 neurona y función de activación sigmoid.
])

# Pueden probar con distintos valores de learning rate y ver cómo afecta el entrenamiento
optimizer = tf.keras.optimizers.Adam(learning_rate=0.5)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

model.fit(x=x, y=y, epochs=50)

plot_results(X1, X2, Y, model)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 2/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 3/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 4/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 5/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 6/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 7/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 8/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 9/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 10/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 11/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 12/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 13/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 14/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 15/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 16/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 17/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 18/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 19/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 20/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 21/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 22/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 23/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 24/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 25/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 26/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 27/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 28/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 29/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 30/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 31/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 32/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 33/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 34/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 35/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 36/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 37/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 38/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 39/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 40/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 41/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 42/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 43/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 44/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 45/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 46/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 47/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 48/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 49/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# Epoch 50/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5454 - accuracy: 0.4820
# 313/313 [==============================] - 0s 978us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 14
#      10 model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
#      12 model.fit(x=x, y=y, epochs=50)
# ---> 14 plot_results(X1, X2, Y, model)
#
# Cell In[18], line 19, in plot_results(X1, X2, Y, model)
#      16 x = np.array([x1.ravel(), x2.ravel()]).T
#      18 # Predict the value for each point in the meshgrid
# ---> 19 y = model.predict(x).reshape(x1.shape)
#      21 # Use cmap red and green
#      22 plt.contourf(x1, x2, y, alpha=0.1, cmap='RdYlGn')
#
# ValueError: cannot reshape array of size 20000 into shape (100,100)
